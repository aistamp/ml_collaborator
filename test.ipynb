# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# %%
print(7 + 16)
# Out:
# 23

# %%
print("Hello all")
# Out:
# Hello all

# %%
9 * 60 * 100
# Out:
# 54000

# %%
x = "test string"
print(x)
# Out:
# test string
